# %%
import numpy as np
import pandas as pd

#!pip install xgboost
import xgboost as xgb

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score

#!pip install shap
import matplotlib.pyplot as plt

# %%
fTest = pd.read_csv('Resources/test.csv')

fTest=fTest.sample(50000)

# %%
dfTrain=pd.read_csv('Resources/train.csv')
dfTrain=dfTrain.sample(50000)

# %%
var_columns=[c for c in dfTrain.columns if c not in ['ID_code', 'target']]
X = dfTrain.loc[:, var_columns]
y=dfTrain.loc[:, 'target']
X_train, X_valid, y_train, y_valid = train_test_split (X,y, test_size=.2)
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((40000, 200), (10000, 200), (40000,), (10000,))

# %%
xgb.XGBClassifier().get_params()
# Out:
# {'objective': 'binary:logistic',
#  'use_label_encoder': True,
#  'base_score': None,
#  'booster': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'enable_categorical': False,
#  'gamma': None,
#  'gpu_id': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'predictor': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %%
model_xgboost = xgb.XGBClassifier(learning_rate=.01,
                                     max_depth=5,
                                     n_estimators=3000,
                                     subsample=.5,
                                     colsample_bytree=.5,
                                     eval_metric='auc',
                                     verbosity=1,
                                    random_state=1)

eval_set =[(X_valid, y_valid)]

model_xgboost.fit(X_train,
                 y_train,
                 early_stopping_rounds=10,
                 eval_set=eval_set,
                 verbose=True)
# Out:
# C:\Users\MW\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [0]	validation_0-auc:0.59713
# [1]	validation_0-auc:0.63256
# [2]	validation_0-auc:0.64794
# [3]	validation_0-auc:0.66539
# [4]	validation_0-auc:0.68281
# [5]	validation_0-auc:0.69532
# [6]	validation_0-auc:0.69578
# [7]	validation_0-auc:0.70263
# [8]	validation_0-auc:0.70588
# [9]	validation_0-auc:0.70861
# [10]	validation_0-auc:0.71042
# [11]	validation_0-auc:0.71267
# [12]	validation_0-auc:0.71900
# [13]	validation_0-auc:0.72066
# [14]	validation_0-auc:0.72251
# [15]	validation_0-auc:0.72560
# [16]	validation_0-auc:0.72573
# [17]	validation_0-auc:0.73029
# [18]	validation_0-auc:0.73186
# [19]	validation_0-auc:0.73198
# [20]	validation_0-auc:0.73171
# [21]	validation_0-auc:0.73635
# [22]	validation_0-auc:0.73622
# [23]	validation_0-auc:0.73645
# [24]	validation_0-auc:0.73655
# [25]	validation_0-auc:0.73793
# [26]	validation_0-auc:0.74088
# [27]	validation_0-auc:0.74309
# [28]	validation_0-auc:0.74526
# [29]	validation_0-auc:0.74624
# [30]	validation_0-auc:0.74611
# [31]	validation_0-auc:0.74571
# [32]	validation_0-auc:0.74630
# [33]	validation_0-auc:0.74782
# [34]	validation_0-auc:0.74867
# [35]	validation_0-auc:0.74998
# [36]	validation_0-auc:0.75080
# [37]	validation_0-auc:0.75018
# [38]	validation_0-auc:0.74987
# [39]	validation_0-auc:0.74900
# [40]	validation_0-auc:0.75085
# [41]	validation_0-auc:0.74952
# [42]	validation_0-auc:0.75106
# [43]	validation_0-auc:0.75218
# [44]	validation_0-auc:0.75347
# [45]	validation_0-auc:0.75433
# [46]	validation_0-auc:0.75536
# [47]	validation_0-auc:0.75562
# [48]	validation_0-auc:0.75584
# [49]	validation_0-auc:0.75576
# [50]	validation_0-auc:0.75567
# [51]	validation_0-auc:0.75600
# [52]	validation_0-auc:0.75650
# [53]	validation_0-auc:0.75597
# [54]	validation_0-auc:0.75677
# [55]	validation_0-auc:0.75702
# [56]	validation_0-auc:0.75649
# [57]	validation_0-auc:0.75724
# [58]	validation_0-auc:0.75725
# [59]	validation_0-auc:0.75743
# [60]	validation_0-auc:0.75860
# [61]	validation_0-auc:0.75910
# [62]	validation_0-auc:0.75924
# [63]	validation_0-auc:0.76058
# [64]	validation_0-auc:0.76138
# [65]	validation_0-auc:0.76189
# [66]	validation_0-auc:0.76298
# [67]	validation_0-auc:0.76286
# [68]	validation_0-auc:0.76274
# [69]	validation_0-auc:0.76239
# [70]	validation_0-auc:0.76294
# [71]	validation_0-auc:0.76243
# [72]	validation_0-auc:0.76210
# [73]	validation_0-auc:0.76323
# [74]	validation_0-auc:0.76484
# [75]	validation_0-auc:0.76485
# [76]	validation_0-auc:0.76543
# [77]	validation_0-auc:0.76556
# [78]	validation_0-auc:0.76523
# [79]	validation_0-auc:0.76520
# [80]	validation_0-auc:0.76516
# [81]	validation_0-auc:0.76547
# [82]	validation_0-auc:0.76590
# [83]	validation_0-auc:0.76547
# [84]	validation_0-auc:0.76551
# [85]	validation_0-auc:0.76606
# [86]	validation_0-auc:0.76679
# [87]	validation_0-auc:0.76680
# [88]	validation_0-auc:0.76678
# [89]	validation_0-auc:0.76656
# [90]	validation_0-auc:0.76630
# [91]	validation_0-auc:0.76658
# [92]	validation_0-auc:0.76687
# [93]	validation_0-auc:0.76672
# [94]	validation_0-auc:0.76739
# [95]	validation_0-auc:0.76836
# [96]	validation_0-auc:0.76849
# [97]	validation_0-auc:0.76846
# [98]	validation_0-auc:0.76813
# [99]	validation_0-auc:0.76804
# [100]	validation_0-auc:0.76713
# [101]	validation_0-auc:0.76778
# [102]	validation_0-auc:0.76799
# [103]	validation_0-auc:0.76753
# [104]	validation_0-auc:0.76717
# [105]	validation_0-auc:0.76741
# [106]	validation_0-auc:0.76748
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.5,
#               enable_categorical=False, eval_metric='auc', gamma=0, gpu_id=-1,
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.01, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=3000, n_jobs=4, num_parallel_tree=1,
#               predictor='auto', random_state=1, reg_alpha=0, reg_lambda=1,
#               scale_pos_weight=1, subsample=0.5, tree_method='exact',
#               validate_parameters=1, verbosity=1)

# %% [markdown]
# # Evaluate Model Performance

# %%
y_train_pred = model_xgboost.predict_proba(X_train)[:,1]
y_valid_pred = model_xgboost.predict_proba(X_valid)[:,1]

print("AUC Train: {:.4f}\nAUC Valid {:.4f}".format(roc_auc_score(y_train, y_train_pred), roc_auc_score(y_valid,y_valid_pred)))
# Out:
# AUC Train: 0.8482
# AUC Valid 0.7685

# %% [markdown]
# # Hyperparameter Tuning

# %%
learning_rate_list = [0.02, 0.05, .1]
num_parallel_tree_list =[1,3,5]
n_estimators_list = [500, 750, 1000]
params_dict = {'learning_rate' : learning_rate_list,
               'num_parallel_tree': num_parallel_tree_list,
               'n_estimators': n_estimators_list}
num_combinations=1
for v in params_dict.values(): num_combinations  *= len (v)
    
print(num_combinations)
params_dict
# Out:
# 27
# {'learning_rate': [0.02, 0.05, 0.1],
#  'num_parallel_tree': [1, 3, 5],
#  'n_estimators': [500, 750, 1000]}

# %%
def my_roc_auc_score(model, X, y): return roc_auc_score(y, model.predict_proba(X)[:,1])
model_xgboost_hp= GridSearchCV(estimator=xgb.XGBClassifier(subsample=.5,
                                                          colsample_bytree=.25,
                                                          eval_metric='auc',
                                                          use_label_encoder=False),
                              param_grid=params_dict,
                              cv=2,
                              scoring=my_roc_auc_score,
                              return_train_score=True,
                              verbose=4)
model_xgboost_hp.fit(X,y)
# Out:
# Fitting 2 folds for each of 27 candidates, totalling 54 fits
# [CV 1/2] END learning_rate=0.02, n_estimators=500, num_parallel_tree=1; total time= 1.1min
# [CV 2/2] END learning_rate=0.02, n_estimators=500, num_parallel_tree=1; total time= 1.0min
# [CV 1/2] END learning_rate=0.02, n_estimators=500, num_parallel_tree=3; total time= 2.9min
# [CV 2/2] END learning_rate=0.02, n_estimators=500, num_parallel_tree=3; total time= 2.5min
# [CV 1/2] END learning_rate=0.02, n_estimators=500, num_parallel_tree=5; total time= 3.9min
# [CV 2/2] END learning_rate=0.02, n_estimators=500, num_parallel_tree=5; total time= 3.9min
# [CV 1/2] END learning_rate=0.02, n_estimators=750, num_parallel_tree=1; total time= 1.3min
# [CV 2/2] END learning_rate=0.02, n_estimators=750, num_parallel_tree=1; total time= 1.3min
# [CV 1/2] END learning_rate=0.02, n_estimators=750, num_parallel_tree=3; total time= 3.6min
# [CV 2/2] END learning_rate=0.02, n_estimators=750, num_parallel_tree=3; total time= 3.5min
# [CV 1/2] END learning_rate=0.02, n_estimators=750, num_parallel_tree=5; total time= 5.8min
# [CV 2/2] END learning_rate=0.02, n_estimators=750, num_parallel_tree=5; total time= 5.8min
# [CV 1/2] END learning_rate=0.02, n_estimators=1000, num_parallel_tree=1; total time= 1.7min
# [CV 2/2] END learning_rate=0.02, n_estimators=1000, num_parallel_tree=1; total time= 1.7min
# [CV 1/2] END learning_rate=0.02, n_estimators=1000, num_parallel_tree=3; total time= 4.7min
# [CV 2/2] END learning_rate=0.02, n_estimators=1000, num_parallel_tree=3; total time= 4.7min
# [CV 1/2] END learning_rate=0.02, n_estimators=1000, num_parallel_tree=5; total time= 7.7min
# [CV 2/2] END learning_rate=0.02, n_estimators=1000, num_parallel_tree=5; total time= 7.8min
# [CV 1/2] END learning_rate=0.05, n_estimators=500, num_parallel_tree=1; total time=  51.3s
# [CV 2/2] END learning_rate=0.05, n_estimators=500, num_parallel_tree=1; total time=  51.2s
# [CV 1/2] END learning_rate=0.05, n_estimators=500, num_parallel_tree=3; total time= 2.4min
# [CV 2/2] END learning_rate=0.05, n_estimators=500, num_parallel_tree=3; total time= 2.4min
# [CV 1/2] END learning_rate=0.05, n_estimators=500, num_parallel_tree=5; total time= 3.9min
# [CV 2/2] END learning_rate=0.05, n_estimators=500, num_parallel_tree=5; total time= 3.9min
# [CV 1/2] END learning_rate=0.05, n_estimators=750, num_parallel_tree=1; total time= 1.3min
# [CV 2/2] END learning_rate=0.05, n_estimators=750, num_parallel_tree=1; total time= 1.3min
# [CV 1/2] END learning_rate=0.05, n_estimators=750, num_parallel_tree=3; total time= 3.5min
# [CV 2/2] END learning_rate=0.05, n_estimators=750, num_parallel_tree=3; total time= 3.5min
# [CV 1/2] END learning_rate=0.05, n_estimators=750, num_parallel_tree=5; total time= 5.8min
# [CV 2/2] END learning_rate=0.05, n_estimators=750, num_parallel_tree=5; total time= 5.8min
# [CV 1/2] END learning_rate=0.05, n_estimators=1000, num_parallel_tree=1; total time= 1.7min
# [CV 2/2] END learning_rate=0.05, n_estimators=1000, num_parallel_tree=1; total time= 1.7min
# [CV 1/2] END learning_rate=0.05, n_estimators=1000, num_parallel_tree=3; total time= 4.7min
# [CV 2/2] END learning_rate=0.05, n_estimators=1000, num_parallel_tree=3; total time= 4.7min
# [CV 1/2] END learning_rate=0.05, n_estimators=1000, num_parallel_tree=5; total time= 7.7min
# [CV 2/2] END learning_rate=0.05, n_estimators=1000, num_parallel_tree=5; total time= 7.8min
# [CV 1/2] END learning_rate=0.1, n_estimators=500, num_parallel_tree=1; total time=  50.8s
# [CV 2/2] END learning_rate=0.1, n_estimators=500, num_parallel_tree=1; total time=  51.0s
# [CV 1/2] END learning_rate=0.1, n_estimators=500, num_parallel_tree=3; total time= 2.3min
# [CV 2/2] END learning_rate=0.1, n_estimators=500, num_parallel_tree=3; total time= 2.4min
# [CV 1/2] END learning_rate=0.1, n_estimators=500, num_parallel_tree=5; total time= 3.9min
# [CV 2/2] END learning_rate=0.1, n_estimators=500, num_parallel_tree=5; total time= 3.9min
# [CV 1/2] END learning_rate=0.1, n_estimators=750, num_parallel_tree=1; total time= 1.2min
# [CV 2/2] END learning_rate=0.1, n_estimators=750, num_parallel_tree=1; total time= 1.2min
# [CV 1/2] END learning_rate=0.1, n_estimators=750, num_parallel_tree=3; total time= 3.5min
# [CV 2/2] END learning_rate=0.1, n_estimators=750, num_parallel_tree=3; total time= 3.5min
# [CV 1/2] END learning_rate=0.1, n_estimators=750, num_parallel_tree=5; total time= 5.7min
# [CV 2/2] END learning_rate=0.1, n_estimators=750, num_parallel_tree=5; total time= 5.7min
# [CV 1/2] END learning_rate=0.1, n_estimators=1000, num_parallel_tree=1; total time= 1.6min
# [CV 2/2] END learning_rate=0.1, n_estimators=1000, num_parallel_tree=1; total time= 1.6min
# [CV 1/2] END learning_rate=0.1, n_estimators=1000, num_parallel_tree=3; total time= 4.6min
# [CV 2/2] END learning_rate=0.1, n_estimators=1000, num_parallel_tree=3; total time= 4.7min
# [CV 1/2] END learning_rate=0.1, n_estimators=1000, num_parallel_tree=5; total time= 7.5min
# [CV 2/2] END learning_rate=0.1, n_estimators=1000, num_parallel_tree=5; total time= 7.5min
# GridSearchCV(cv=2,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=0.25,
#                                      enable_categorical=False,
#                                      eval_metric='auc', gamma=None, gpu_id=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone...
#                                      random_state=None, reg_alpha=None,
#                                      reg_lambda=None, scale_pos_weight=None,
#                                      subsample=0.5, tree_method=None,
#                                      use_label_encoder=False,
#                                      validate_parameters=None, verbosity=None),
#              param_grid={'learning_rate': [0.02, 0.05, 0.1],
#                          'n_estimators': [500, 750, 1000],
#                          'num_parallel_tree': [1, 3, 5]},
#              return_train_score=True,
#              scoring=<function my_roc_auc_score at 0x000002481C4344C0>,
#              verbose=4)

# %%
df_cv_results = pd.DataFrame(model_xgboost_hp.cv_results_)
Model2Results = df_cv_results[['rank_test_score', 'mean_test_score', 'param_learning_rate', 'param_num_parallel_tree', 'param_n_estimators' ]]
Model2Results.sort_values(by='rank_test_score', inplace=True)
Model2Results
# Out:
# <ipython-input-16-bc312e9e6d67>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Model2Results.sort_values(by='rank_test_score', inplace=True)
#     rank_test_score  mean_test_score param_learning_rate  \
# 8                 1         0.882748                0.02
# 17                2         0.882553                0.05
# 14                3         0.882526                0.05
# 26                4         0.881940                 0.1
# 7                 5         0.881830                0.02
# 11                6         0.881615                0.05
# 23                7         0.881182                 0.1
# 16                8         0.881108                0.05
# 13                9         0.880545                0.05
# 25               10         0.880287                 0.1
# 20               11         0.880255                 0.1
# 5                12         0.880091                0.02
# 10               13         0.879449                0.05
# 4                14         0.879320                0.02
# 22               15         0.879120                 0.1
# 19               16         0.877808                 0.1
# 6                17         0.876169                0.02
# 2                18         0.873800                0.02
# 3                19         0.872618                0.02
# 1                20         0.872613                0.02
# 15               21         0.871815                0.05
# 12               22         0.870536                0.05
# 24               23         0.870295                 0.1
# 9                24         0.868257                0.05
# 21               25         0.867139                 0.1
# 0                26         0.865688                0.02
# 18               27         0.862558                 0.1
#
#    param_num_parallel_tree param_n_estimators
# 8                        5               1000
# 17                       5               1000
# 14                       5                750
# 26                       5               1000
# 7                        3               1000
# 11                       5                500
# 23                       5                750
# 16                       3               1000
# 13                       3                750
# 25                       3               1000
# 20                       5                500
# 5                        5                750
# 10                       3                500
# 4                        3                750
# 22                       3                750
# 19                       3                500
# 6                        1               1000
# 2                        5                500
# 3                        1                750
# 1                        3                500
# 15                       1               1000
# 12                       1                750
# 24                       1               1000
# 9                        1                500
# 21                       1                750
# 0                        1                500
# 18                       1                500

# %%
Model2Results.to_csv('output/model2.csv')
