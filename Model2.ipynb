# %%
import numpy as np
import pandas as pd

#!pip install xgboost
import xgboost as xgb

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score

#!pip install shap
import matplotlib.pyplot as plt

# %%
fTest = pd.read_csv('Resources/test.csv')

fTest=fTest.sample(50000)

# %%
dfTrain=pd.read_csv('Resources/train.csv')
dfTrain=dfTrain.sample(50000)

# %%
var_columns=[c for c in dfTrain.columns if c not in ['ID_code', 'target']]
X = dfTrain.loc[:, var_columns]
y=dfTrain.loc[:, 'target']
X_train, X_valid, y_train, y_valid = train_test_split (X,y, test_size=.2)
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((40000, 200), (10000, 200), (40000,), (10000,))

# %%
xgb.XGBClassifier().get_params()
# Out:
# {'objective': 'binary:logistic',
#  'use_label_encoder': True,
#  'base_score': None,
#  'booster': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'enable_categorical': False,
#  'gamma': None,
#  'gpu_id': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'predictor': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %%
model_xgboost = xgb.XGBClassifier(learning_rate=.01,
                                     max_depth=5,
                                     n_estimators=3000,
                                     subsample=.5,
                                     colsample_bytree=.5,
                                     eval_metric='auc',
                                     verbosity=1,
                                    random_state=1)

eval_set =[(X_valid, y_valid)]

model_xgboost.fit(X_train,
                 y_train,
                 early_stopping_rounds=10,
                 eval_set=eval_set,
                 verbose=True)
# Out:
# C:\Users\MW\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [0]	validation_0-auc:0.59643
# [1]	validation_0-auc:0.62884
# [2]	validation_0-auc:0.65616
# [3]	validation_0-auc:0.67579
# [4]	validation_0-auc:0.67798
# [5]	validation_0-auc:0.69998
# [6]	validation_0-auc:0.70079
# [7]	validation_0-auc:0.69981
# [8]	validation_0-auc:0.70430
# [9]	validation_0-auc:0.70607
# [10]	validation_0-auc:0.70820
# [11]	validation_0-auc:0.70917
# [12]	validation_0-auc:0.71121
# [13]	validation_0-auc:0.71606
# [14]	validation_0-auc:0.72355
# [15]	validation_0-auc:0.72152
# [16]	validation_0-auc:0.72034
# [17]	validation_0-auc:0.72050
# [18]	validation_0-auc:0.72529
# [19]	validation_0-auc:0.72828
# [20]	validation_0-auc:0.72739
# [21]	validation_0-auc:0.73054
# [22]	validation_0-auc:0.73064
# [23]	validation_0-auc:0.73390
# [24]	validation_0-auc:0.73580
# [25]	validation_0-auc:0.73842
# [26]	validation_0-auc:0.73817
# [27]	validation_0-auc:0.74008
# [28]	validation_0-auc:0.74162
# [29]	validation_0-auc:0.74099
# [30]	validation_0-auc:0.74224
# [31]	validation_0-auc:0.74079
# [32]	validation_0-auc:0.74047
# [33]	validation_0-auc:0.74207
# [34]	validation_0-auc:0.74281
# [35]	validation_0-auc:0.74357
# [36]	validation_0-auc:0.74476
# [37]	validation_0-auc:0.74474
# [38]	validation_0-auc:0.74527
# [39]	validation_0-auc:0.74581
# [40]	validation_0-auc:0.74671
# [41]	validation_0-auc:0.74587
# [42]	validation_0-auc:0.74676
# [43]	validation_0-auc:0.74645
# [44]	validation_0-auc:0.74687
# [45]	validation_0-auc:0.74604
# [46]	validation_0-auc:0.74746
# [47]	validation_0-auc:0.74882
# [48]	validation_0-auc:0.75148
# [49]	validation_0-auc:0.75203
# [50]	validation_0-auc:0.75257
# [51]	validation_0-auc:0.75227
# [52]	validation_0-auc:0.75135
# [53]	validation_0-auc:0.75233
# [54]	validation_0-auc:0.75279
# [55]	validation_0-auc:0.75334
# [56]	validation_0-auc:0.75361
# [57]	validation_0-auc:0.75329
# [58]	validation_0-auc:0.75414
# [59]	validation_0-auc:0.75402
# [60]	validation_0-auc:0.75489
# [61]	validation_0-auc:0.75521
# [62]	validation_0-auc:0.75530
# [63]	validation_0-auc:0.75612
# [64]	validation_0-auc:0.75719
# [65]	validation_0-auc:0.75925
# [66]	validation_0-auc:0.76019
# [67]	validation_0-auc:0.76057
# [68]	validation_0-auc:0.76179
# [69]	validation_0-auc:0.76086
# [70]	validation_0-auc:0.76074
# [71]	validation_0-auc:0.76112
# [72]	validation_0-auc:0.76078
# [73]	validation_0-auc:0.76114
# [74]	validation_0-auc:0.76162
# [75]	validation_0-auc:0.76303
# [76]	validation_0-auc:0.76320
# [77]	validation_0-auc:0.76422
# [78]	validation_0-auc:0.76390
# [79]	validation_0-auc:0.76382
# [80]	validation_0-auc:0.76380
# [81]	validation_0-auc:0.76414
# [82]	validation_0-auc:0.76442
# [83]	validation_0-auc:0.76460
# [84]	validation_0-auc:0.76465
# [85]	validation_0-auc:0.76506
# [86]	validation_0-auc:0.76641
# [87]	validation_0-auc:0.76677
# [88]	validation_0-auc:0.76776
# [89]	validation_0-auc:0.76809
# [90]	validation_0-auc:0.76851
# [91]	validation_0-auc:0.76895
# [92]	validation_0-auc:0.76963
# [93]	validation_0-auc:0.76970
# [94]	validation_0-auc:0.77020
# [95]	validation_0-auc:0.76986
# [96]	validation_0-auc:0.77058
# [97]	validation_0-auc:0.77093
# [98]	validation_0-auc:0.77111
# [99]	validation_0-auc:0.77094
# [100]	validation_0-auc:0.77179
# [101]	validation_0-auc:0.77233
# [102]	validation_0-auc:0.77192
# [103]	validation_0-auc:0.77177
# [104]	validation_0-auc:0.77130
# [105]	validation_0-auc:0.77123
# [106]	validation_0-auc:0.77170
# [107]	validation_0-auc:0.77177
# [108]	validation_0-auc:0.77239
# [109]	validation_0-auc:0.77283
# [110]	validation_0-auc:0.77272
# [111]	validation_0-auc:0.77339
# [112]	validation_0-auc:0.77258
# [113]	validation_0-auc:0.77340
# [114]	validation_0-auc:0.77332
# [115]	validation_0-auc:0.77320
# [116]	validation_0-auc:0.77300
# [117]	validation_0-auc:0.77311
# [118]	validation_0-auc:0.77355
# [119]	validation_0-auc:0.77331
# [120]	validation_0-auc:0.77438
# [121]	validation_0-auc:0.77520
# [122]	validation_0-auc:0.77493
# [123]	validation_0-auc:0.77516
# [124]	validation_0-auc:0.77582
# [125]	validation_0-auc:0.77677
# [126]	validation_0-auc:0.77696
# [127]	validation_0-auc:0.77630
# [128]	validation_0-auc:0.77545
# [129]	validation_0-auc:0.77558
# [130]	validation_0-auc:0.77590
# [131]	validation_0-auc:0.77565
# [132]	validation_0-auc:0.77599
# [133]	validation_0-auc:0.77606
# [134]	validation_0-auc:0.77654
# [135]	validation_0-auc:0.77640
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.5,
#               enable_categorical=False, eval_metric='auc', gamma=0, gpu_id=-1,
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.01, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=3000, n_jobs=4, num_parallel_tree=1,
#               predictor='auto', random_state=1, reg_alpha=0, reg_lambda=1,
#               scale_pos_weight=1, subsample=0.5, tree_method='exact',
#               validate_parameters=1, verbosity=1)

# %% [markdown]
# # Evaluate Model Performance

# %%
y_train_pred = model_xgboost.predict_proba(X_train)[:,1]
y_valid_pred = model_xgboost.predict_proba(X_valid)[:,1]

print("AUC Train: {:.4f}\nAUC Valid {:.4f}".format(roc_auc_score(y_train, y_train_pred), roc_auc_score(y_valid,y_valid_pred)))
# Out:
# AUC Train: 0.8448
# AUC Valid 0.7770

# %% [markdown]
# # Hyperparameter Tuning

# %%
learning_rate_list = [0.02, 0.05, .1]
num_parallel_tree_list =[1,3,5]
n_estimators_list = [500, 750, 1000]
params_dict = {'learning_rate' : learning_rate_list,
               'num_parallel_tree': num_parallel_tree_list,
               'n_estimators': n_estimators_list}
num_combinations=1
for v in params_dict.values(): num_combinations  *= len (v)
    
print(num_combinations)
params_dict
# Out:
# 27
# {'learning_rate': [0.02, 0.05, 0.1],
#  'num_parallel_tree': [1, 3, 5],
#  'n_estimators': [500, 750, 1000]}

# %%
def my_roc_auc_score(model, X, y): return roc_auc_score(y, model.predict_proba(X)[:,1])
model_xgboost_hp= GridSearchCV(estimator=xgb.XGBClassifier(subsample=.5,
                                                          colsample_bytree=.25,
                                                          eval_metric='auc',
                                                          use_label_encoder=False),
                              param_grid=params_dict,
                              cv=2,
                              scoring=my_roc_auc_score,
                              return_train_score=True,
                              verbose=4)
model_xgboost_hp.fit(X,y)
# Out:
# Fitting 2 folds for each of 27 candidates, totalling 54 fits
# [CV 1/2] END learning_rate=0.02, n_estimators=500, num_parallel_tree=1; total time=  50.4s
# [CV 2/2] END learning_rate=0.02, n_estimators=500, num_parallel_tree=1; total time=  49.4s
# [CV 1/2] END learning_rate=0.02, n_estimators=500, num_parallel_tree=3; total time= 2.3min
# [CV 2/2] END learning_rate=0.02, n_estimators=500, num_parallel_tree=3; total time= 2.3min
# [CV 1/2] END learning_rate=0.02, n_estimators=500, num_parallel_tree=5; total time= 3.9min
# [CV 2/2] END learning_rate=0.02, n_estimators=500, num_parallel_tree=5; total time= 3.8min
# [CV 1/2] END learning_rate=0.02, n_estimators=750, num_parallel_tree=1; total time= 1.2min
# [CV 2/2] END learning_rate=0.02, n_estimators=750, num_parallel_tree=1; total time= 1.2min
# [CV 1/2] END learning_rate=0.02, n_estimators=750, num_parallel_tree=3; total time= 3.5min
# [CV 2/2] END learning_rate=0.02, n_estimators=750, num_parallel_tree=3; total time= 3.5min
# [CV 1/2] END learning_rate=0.02, n_estimators=750, num_parallel_tree=5; total time= 5.7min
# [CV 2/2] END learning_rate=0.02, n_estimators=750, num_parallel_tree=5; total time= 6.0min
# [CV 1/2] END learning_rate=0.02, n_estimators=1000, num_parallel_tree=1; total time= 1.7min
# [CV 2/2] END learning_rate=0.02, n_estimators=1000, num_parallel_tree=1; total time= 1.7min
# [CV 1/2] END learning_rate=0.02, n_estimators=1000, num_parallel_tree=3; total time= 4.7min
# [CV 2/2] END learning_rate=0.02, n_estimators=1000, num_parallel_tree=3; total time= 4.6min
# [CV 1/2] END learning_rate=0.02, n_estimators=1000, num_parallel_tree=5; total time= 7.7min
# [CV 2/2] END learning_rate=0.02, n_estimators=1000, num_parallel_tree=5; total time= 7.6min
# [CV 1/2] END learning_rate=0.05, n_estimators=500, num_parallel_tree=1; total time=  49.7s
# [CV 2/2] END learning_rate=0.05, n_estimators=500, num_parallel_tree=1; total time=  49.6s
# [CV 1/2] END learning_rate=0.05, n_estimators=500, num_parallel_tree=3; total time= 2.4min
# [CV 2/2] END learning_rate=0.05, n_estimators=500, num_parallel_tree=3; total time= 2.3min
# [CV 1/2] END learning_rate=0.05, n_estimators=500, num_parallel_tree=5; total time= 3.9min
# [CV 2/2] END learning_rate=0.05, n_estimators=500, num_parallel_tree=5; total time= 3.9min
# [CV 1/2] END learning_rate=0.05, n_estimators=750, num_parallel_tree=1; total time= 1.3min
# [CV 2/2] END learning_rate=0.05, n_estimators=750, num_parallel_tree=1; total time= 1.2min
# [CV 1/2] END learning_rate=0.05, n_estimators=750, num_parallel_tree=3; total time= 3.5min
# [CV 2/2] END learning_rate=0.05, n_estimators=750, num_parallel_tree=3; total time= 3.5min
# [CV 1/2] END learning_rate=0.05, n_estimators=750, num_parallel_tree=5; total time= 5.8min
# [CV 2/2] END learning_rate=0.05, n_estimators=750, num_parallel_tree=5; total time= 5.8min
# [CV 1/2] END learning_rate=0.05, n_estimators=1000, num_parallel_tree=1; total time= 1.7min
# [CV 2/2] END learning_rate=0.05, n_estimators=1000, num_parallel_tree=1; total time= 1.7min
# [CV 1/2] END learning_rate=0.05, n_estimators=1000, num_parallel_tree=3; total time= 4.6min
# [CV 2/2] END learning_rate=0.05, n_estimators=1000, num_parallel_tree=3; total time= 4.6min
# [CV 1/2] END learning_rate=0.05, n_estimators=1000, num_parallel_tree=5; total time= 7.6min
# [CV 2/2] END learning_rate=0.05, n_estimators=1000, num_parallel_tree=5; total time= 7.5min
# [CV 1/2] END learning_rate=0.1, n_estimators=500, num_parallel_tree=1; total time=  49.9s
# [CV 2/2] END learning_rate=0.1, n_estimators=500, num_parallel_tree=1; total time=  49.3s
# [CV 1/2] END learning_rate=0.1, n_estimators=500, num_parallel_tree=3; total time= 2.3min
# [CV 2/2] END learning_rate=0.1, n_estimators=500, num_parallel_tree=3; total time= 2.3min
# [CV 1/2] END learning_rate=0.1, n_estimators=500, num_parallel_tree=5; total time= 3.8min
# [CV 2/2] END learning_rate=0.1, n_estimators=500, num_parallel_tree=5; total time= 3.8min
# [CV 1/2] END learning_rate=0.1, n_estimators=750, num_parallel_tree=1; total time= 1.2min
# [CV 2/2] END learning_rate=0.1, n_estimators=750, num_parallel_tree=1; total time= 1.2min
# [CV 1/2] END learning_rate=0.1, n_estimators=750, num_parallel_tree=3; total time= 3.4min
# [CV 2/2] END learning_rate=0.1, n_estimators=750, num_parallel_tree=3; total time= 3.4min
# [CV 1/2] END learning_rate=0.1, n_estimators=750, num_parallel_tree=5; total time= 5.6min
# [CV 2/2] END learning_rate=0.1, n_estimators=750, num_parallel_tree=5; total time= 5.6min
# [CV 1/2] END learning_rate=0.1, n_estimators=1000, num_parallel_tree=1; total time= 1.6min
# [CV 2/2] END learning_rate=0.1, n_estimators=1000, num_parallel_tree=1; total time= 1.6min
# [CV 1/2] END learning_rate=0.1, n_estimators=1000, num_parallel_tree=3; total time= 4.6min
# [CV 2/2] END learning_rate=0.1, n_estimators=1000, num_parallel_tree=3; total time= 4.5min
# [CV 1/2] END learning_rate=0.1, n_estimators=1000, num_parallel_tree=5; total time= 7.4min
# [CV 2/2] END learning_rate=0.1, n_estimators=1000, num_parallel_tree=5; total time= 7.4min
# GridSearchCV(cv=2,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=0.25,
#                                      enable_categorical=False,
#                                      eval_metric='auc', gamma=None, gpu_id=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone...
#                                      random_state=None, reg_alpha=None,
#                                      reg_lambda=None, scale_pos_weight=None,
#                                      subsample=0.5, tree_method=None,
#                                      use_label_encoder=False,
#                                      validate_parameters=None, verbosity=None),
#              param_grid={'learning_rate': [0.02, 0.05, 0.1],
#                          'n_estimators': [500, 750, 1000],
#                          'num_parallel_tree': [1, 3, 5]},
#              return_train_score=True,
#              scoring=<function my_roc_auc_score at 0x0000027EDA155310>,
#              verbose=4)

# %%
df_cv_results2 = pd.DataFrame(model_xgboost_hp.cv_results_)
df_cv_reults2 = df_cv_results2[['rank_test_score', 'mean_test_score', 'param_learning_rate', 'param_num_parallel_tree', 'param_n_estimators' ]]
df_cv_results2.sort_values(by='rank_test_score', inplace=True)
df_cv_results2
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 8      457.407718      1.221733         1.362300        0.007978
# 17     453.024094      1.410879         1.442583        0.011466
# 7      279.143487      1.184830         0.828726        0.006983
# 14     345.500003      1.406228         1.066105        0.002981
# 26     441.481256      0.848730         1.359365        0.008976
# 5      349.889020      6.370701         1.025711        0.009489
# 11     230.892536      0.007978         0.707051        0.011968
# 23     336.117235      0.469618         1.054152        0.006012
# 16     276.950909      1.071746         0.838256        0.019448
# 13     208.805068      0.271790         0.636780        0.012450
# 4      208.845461      0.380965         0.638274        0.008992
# 20     228.588684      0.402934         0.708560        0.003479
# 10     140.164159      1.050219         0.452761        0.012993
# 25     270.467135      1.929340         1.033736        0.086269
# 22     204.958869      0.625327         0.637263        0.003989
# 6       99.669462      0.534542         0.315628        0.001468
# 19     138.300630      0.251811         0.438313        0.009491
# 2      228.769318      2.002481         0.727538        0.011486
# 3       74.548151      0.028452         0.240826        0.000527
# 15      99.377746      0.253821         0.309141        0.006982
# 1      139.313583      0.991226         0.438300        0.005459
# 12      74.763573      0.371535         0.248809        0.000525
# 9       49.576465      0.051862         0.178964        0.000500
# 24      96.224166      0.277742         0.300180        0.000982
# 0       49.814799      0.469715         0.182483        0.003961
# 21      73.432633      0.396911         0.242323        0.002023
# 18      49.491679      0.292231         0.180971        0.003478
#
#    param_learning_rate param_n_estimators param_num_parallel_tree  \
# 8                 0.02               1000                       5
# 17                0.05               1000                       5
# 7                 0.02               1000                       3
# 14                0.05                750                       5
# 26                 0.1               1000                       5
# 5                 0.02                750                       5
# 11                0.05                500                       5
# 23                 0.1                750                       5
# 16                0.05               1000                       3
# 13                0.05                750                       3
# 4                 0.02                750                       3
# 20                 0.1                500                       5
# 10                0.05                500                       3
# 25                 0.1               1000                       3
# 22                 0.1                750                       3
# 6                 0.02               1000                       1
# 19                 0.1                500                       3
# 2                 0.02                500                       5
# 3                 0.02                750                       1
# 15                0.05               1000                       1
# 1                 0.02                500                       3
# 12                0.05                750                       1
# 9                 0.05                500                       1
# 24                 0.1               1000                       1
# 0                 0.02                500                       1
# 21                 0.1                750                       1
# 18                 0.1                500                       1
#
#                                                params  split0_test_score  \
# 8   {'learning_rate': 0.02, 'n_estimators': 1000, ...           0.883459
# 17  {'learning_rate': 0.05, 'n_estimators': 1000, ...           0.881281
# 7   {'learning_rate': 0.02, 'n_estimators': 1000, ...           0.881889
# 14  {'learning_rate': 0.05, 'n_estimators': 750, '...           0.881066
# 26  {'learning_rate': 0.1, 'n_estimators': 1000, '...           0.881371
# 5   {'learning_rate': 0.02, 'n_estimators': 750, '...           0.881032
# 11  {'learning_rate': 0.05, 'n_estimators': 500, '...           0.880457
# 23  {'learning_rate': 0.1, 'n_estimators': 750, 'n...           0.880423
# 16  {'learning_rate': 0.05, 'n_estimators': 1000, ...           0.879495
# 13  {'learning_rate': 0.05, 'n_estimators': 750, '...           0.879643
# 4   {'learning_rate': 0.02, 'n_estimators': 750, '...           0.879596
# 20  {'learning_rate': 0.1, 'n_estimators': 500, 'n...           0.879214
# 10  {'learning_rate': 0.05, 'n_estimators': 500, '...           0.878145
# 25  {'learning_rate': 0.1, 'n_estimators': 1000, '...           0.878057
# 22  {'learning_rate': 0.1, 'n_estimators': 750, 'n...           0.877010
# 6   {'learning_rate': 0.02, 'n_estimators': 1000, ...           0.878413
# 19  {'learning_rate': 0.1, 'n_estimators': 500, 'n...           0.874984
# 2   {'learning_rate': 0.02, 'n_estimators': 500, '...           0.875925
# 3   {'learning_rate': 0.02, 'n_estimators': 750, '...           0.876172
# 15  {'learning_rate': 0.05, 'n_estimators': 1000, ...           0.873652
# 1   {'learning_rate': 0.02, 'n_estimators': 500, '...           0.872933
# 12  {'learning_rate': 0.05, 'n_estimators': 750, '...           0.872354
# 9   {'learning_rate': 0.05, 'n_estimators': 500, '...           0.870337
# 24  {'learning_rate': 0.1, 'n_estimators': 1000, '...           0.867307
# 0   {'learning_rate': 0.02, 'n_estimators': 500, '...           0.868805
# 21  {'learning_rate': 0.1, 'n_estimators': 750, 'n...           0.864625
# 18  {'learning_rate': 0.1, 'n_estimators': 500, 'n...           0.861986
#
#     split1_test_score  mean_test_score  std_test_score  rank_test_score  \
# 8            0.881575         0.882517        0.000942                1
# 17           0.880314         0.880797        0.000483                2
# 7            0.879683         0.880786        0.001103                3
# 14           0.880070         0.880568        0.000498                4
# 26           0.878880         0.880126        0.001245                5
# 5            0.878631         0.879831        0.001200                6
# 11           0.878956         0.879707        0.000750                7
# 23           0.877835         0.879129        0.001294                8
# 16           0.878476         0.878985        0.000510                9
# 13           0.878194         0.878918        0.000724               10
# 4            0.876832         0.878214        0.001382               11
# 20           0.876404         0.877809        0.001405               12
# 10           0.877043         0.877594        0.000551               13
# 25           0.876495         0.877276        0.000781               14
# 22           0.874869         0.875940        0.001070               15
# 6            0.873294         0.875854        0.002559               16
# 19           0.873485         0.874235        0.000750               17
# 2            0.871864         0.873895        0.002031               18
# 3            0.869898         0.873035        0.003137               19
# 15           0.870060         0.871856        0.001796               20
# 1            0.870214         0.871573        0.001360               21
# 12           0.869087         0.870720        0.001633               22
# 9            0.866256         0.868296        0.002041               23
# 24           0.864667         0.865987        0.001320               24
# 0            0.861768         0.865287        0.003519               25
# 21           0.861646         0.863135        0.001489               26
# 18           0.857943         0.859964        0.002022               27
#
#     split0_train_score  split1_train_score  mean_train_score  std_train_score
# 8             0.999871            0.999940          0.999906     3.424651e-05
# 17            1.000000            1.000000          1.000000     0.000000e+00
# 7             0.999834            0.999943          0.999889     5.434734e-05
# 14            1.000000            1.000000          1.000000     0.000000e+00
# 26            1.000000            1.000000          1.000000     0.000000e+00
# 5             0.999343            0.999558          0.999450     1.077581e-04
# 11            0.999974            0.999988          0.999981     6.564798e-06
# 23            1.000000            1.000000          1.000000     0.000000e+00
# 16            1.000000            1.000000          1.000000     0.000000e+00
# 13            1.000000            1.000000          1.000000     8.835528e-09
# 4             0.999273            0.999570          0.999422     1.486578e-04
# 20            1.000000            1.000000          1.000000     0.000000e+00
# 10            0.999972            0.999976          0.999974     2.244224e-06
# 25            1.000000            1.000000          1.000000     0.000000e+00
# 22            1.000000            1.000000          1.000000     0.000000e+00
# 6             0.999805            0.999828          0.999817     1.138900e-05
# 19            1.000000            1.000000          1.000000     0.000000e+00
# 2             0.996863            0.997279          0.997071     2.080634e-04
# 3             0.999229            0.999373          0.999301     7.196538e-05
# 15            1.000000            1.000000          1.000000     0.000000e+00
# 1             0.996743            0.997113          0.996928     1.850160e-04
# 12            1.000000            1.000000          1.000000     3.534211e-08
# 9             0.999938            0.999968          0.999953     1.495855e-05
# 24            1.000000            1.000000          1.000000     0.000000e+00
# 0             0.996350            0.996298          0.996324     2.600738e-05
# 21            1.000000            1.000000          1.000000     0.000000e+00
# 18            1.000000            1.000000          1.000000     0.000000e+00

# %%
df_cv_results2.to_csv('output/model2.csv')
